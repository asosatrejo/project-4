# %%
import pandas as pd

# %%
# Create Data Frame
annual_aqi_df = pd.DataFrame()

# Obatin csv files
csv_files = []
for x in range(0, 10):
    name = f"Resources/annual_aqi_by_county_200{x}.csv"
    csv_files.append(name)

for x in range(10, 23):
    name = f"Resources/annual_aqi_by_county_20{x}.csv"
    csv_files.append(name)
    
for x in range(80, 100):
    name = f"Resources/annual_aqi_by_county_19{x}.csv"
    csv_files.append(name)

# Append all files together
for file in csv_files:
            df_temp = pd.read_csv(file)
            annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# Out:
# C:\Users\arian\AppData\Local\Temp\ipykernel_2064\966517947.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_2064\966517947.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_2064\966517947.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_2064\966517947.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_2064\966517947.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_2064\966517947.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_2064\966517947.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_2064\966517947.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_2064\966517947.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_2064\966517947.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_2064\966517947.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_2064\966517947.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_2064\966517947.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_2064\966517947.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_2064\966517947.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_2064\966517947.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_2064\966517947.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_2064\966517947.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_2064\966517947.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_2064\966517947.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_2064\966517947.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_2064\966517947.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_2064\966517947.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_2064\966517947.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_2064\966517947.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_2064\966517947.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_2064\966517947.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_2064\966517947.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_2064\966517947.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_2064\966517947.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_2064\966517947.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_2064\966517947.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_2064\966517947.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_2064\966517947.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_2064\966517947.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_2064\966517947.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_2064\966517947.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_2064\966517947.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_2064\966517947.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_2064\966517947.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_2064\966517947.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_2064\966517947.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_2064\966517947.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)

# %%
# View Data Frame
annual_aqi_df
# Out:
#          State      County  Year  Days with AQI  Good Days  Moderate Days  \
# 0      Alabama     Baldwin  2000            257        111             96
# 1      Alabama        Clay  2000            271        155            101
# 2      Alabama     Colbert  2000            106         38             66
# 3      Alabama      DeKalb  2000            354        169            123
# 4      Alabama      Elmore  2000            242        125             78
# ...        ...         ...   ...            ...        ...            ...
# 39507  Wyoming      Platte  1999             60         60              0
# 39508  Wyoming    Sheridan  1999            283        225             58
# 39509  Wyoming    Sublette  1999            361        204            150
# 39510  Wyoming  Sweetwater  1999             63         58              5
# 39511  Wyoming       Teton  1999            355        256             95
#
#        Unhealthy for Sensitive Groups Days  Unhealthy Days  \
# 0                                       39              10
# 1                                       14               1
# 2                                        2               0
# 3                                       58               4
# 4                                       37               2
# ...                                    ...             ...
# 39507                                    0               0
# 39508                                    0               0
# 39509                                    7               0
# 39510                                    0               0
# 39511                                    4               0
#
#        Very Unhealthy Days  Hazardous Days  Max AQI  90th Percentile AQI  \
# 0                        1               0      205                  129
# 1                        0               0      177                   90
# 2                        0               0      124                   80
# 3                        0               0      159                  115
# 4                        0               0      166                  112
# ...                    ...             ...      ...                  ...
# 39507                    0               0       42                   30
# 39508                    0               0       98                   59
# 39509                    0               0      126                   74
# 39510                    0               0       63                   48
# 39511                    0               0      126                   68
#
#        Median AQI  Days CO  Days NO2  Days Ozone  Days PM2.5  Days PM10
# 0              54        0         0         215          42          0
# 1              46        0         0         188          83          0
# 2              58        0         0           0         106          0
# 3              51        0         0         297          56          1
# 4              50        0         0         242           0          0
# ...           ...      ...       ...         ...         ...        ...
# 39507          13        0         0           0           0         60
# 39508          31        0         0           0         101        182
# 39509          48        0         0         360           1          0
# 39510          26        0         0           0           0         63
# 39511          45        0         0         351           2          2
#
# [39512 rows x 18 columns]

# %%
# Set 'State' to index
annual_aqi_df = annual_aqi_df.set_index("State")

annual_aqi_df.head()
# Out:
#           County  Year  Days with AQI  Good Days  Moderate Days  \
# State
# Alabama  Baldwin  2000            257        111             96
# Alabama     Clay  2000            271        155            101
# Alabama  Colbert  2000            106         38             66
# Alabama   DeKalb  2000            354        169            123
# Alabama   Elmore  2000            242        125             78
#
#          Unhealthy for Sensitive Groups Days  Unhealthy Days  \
# State
# Alabama                                   39              10
# Alabama                                   14               1
# Alabama                                    2               0
# Alabama                                   58               4
# Alabama                                   37               2
#
#          Very Unhealthy Days  Hazardous Days  Max AQI  90th Percentile AQI  \
# State
# Alabama                    1               0      205                  129
# Alabama                    0               0      177                   90
# Alabama                    0               0      124                   80
# Alabama                    0               0      159                  115
# Alabama                    0               0      166                  112
#
#          Median AQI  Days CO  Days NO2  Days Ozone  Days PM2.5  Days PM10
# State
# Alabama          54        0         0         215          42          0
# Alabama          46        0         0         188          83          0
# Alabama          58        0         0           0         106          0
# Alabama          51        0         0         297          56          1
# Alabama          50        0         0         242           0          0

# %%
# Obtain NC data
nc_aqi_df = annual_aqi_df.loc[["North Carolina"]]
nc_aqi_df
# Out:
#                    County  Year  Days with AQI  Good Days  Moderate Days  \
# State
# North Carolina   Alamance  2000            104         37             66
# North Carolina  Alexander  2000            211         94             64
# North Carolina      Avery  2000            365        211            117
# North Carolina   Buncombe  2000            260        129            110
# North Carolina   Cabarrus  2000            115         36             78
# ...                   ...   ...            ...        ...            ...
# North Carolina      Swain  1999            257        116            128
# North Carolina      Union  1999            188         95             53
# North Carolina       Wake  1999            363        134            156
# North Carolina      Wayne  1999            110         54             51
# North Carolina     Yancey  1999            179         41             93
#
#                 Unhealthy for Sensitive Groups Days  Unhealthy Days  \
# State
# North Carolina                                    1               0
# North Carolina                                   48               5
# North Carolina                                   34               3
# North Carolina                                   15               6
# North Carolina                                    1               0
# ...                                             ...             ...
# North Carolina                                   13               0
# North Carolina                                   27              13
# North Carolina                                   41              23
# North Carolina                                    5               0
# North Carolina                                   35              10
#
#                 Very Unhealthy Days  Hazardous Days  Max AQI  \
# State
# North Carolina                    0               0      104
# North Carolina                    0               0      182
# North Carolina                    0               0      172
# North Carolina                    0               0      179
# North Carolina                    0               0      118
# ...                             ...             ...      ...
# North Carolina                    0               0      140
# North Carolina                    0               0      187
# North Carolina                    9               0      220
# North Carolina                    0               0      117
# North Carolina                    0               0      185
#
#                 90th Percentile AQI  Median AQI  Days CO  Days NO2  \
# State
# North Carolina                   76          56        0         0
# North Carolina                  126          58        0         0
# North Carolina                  101          47        0         0
# North Carolina                   93          51        0         0
# North Carolina                   86          56        0         0
# ...                             ...         ...      ...       ...
# North Carolina                   93          54        0         0
# North Carolina                  133          50        0         0
# North Carolina                  143          58       21         0
# North Carolina                   83          52        0         0
# North Carolina                  133          74        0         0
#
#                 Days Ozone  Days PM2.5  Days PM10
# State
# North Carolina           0         104          0
# North Carolina         211           0          0
# North Carolina         353          12          0
# North Carolina         176          84          0
# North Carolina           0         114          1
# ...                    ...         ...        ...
# North Carolina         173          82          2
# North Carolina         188           0          0
# North Carolina         161         181          0
# North Carolina           0          93         17
# North Carolina         179           0          0
#
# [1587 rows x 17 columns]

# %%
# Save Data Frame as new csv
nc_aqi_df.to_csv('Resources/nc_aqi_1980-2022.csv')
