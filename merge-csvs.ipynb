# %%
import pandas as pd

# %%
# Create Data Frame
annual_aqi_df = pd.DataFrame()

# Obatin csv files
csv_files = []
for x in range(10, 23):
    name = f"Resources/annual_aqi_by_county_20{x}.csv"
    csv_files.append(name)

# Append all files together
for file in csv_files:
            df_temp = pd.read_csv(file)
            annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# Out:
# C:\Users\arian\AppData\Local\Temp\ipykernel_20984\4005375141.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_20984\4005375141.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_20984\4005375141.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_20984\4005375141.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_20984\4005375141.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_20984\4005375141.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_20984\4005375141.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_20984\4005375141.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_20984\4005375141.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_20984\4005375141.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_20984\4005375141.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_20984\4005375141.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_20984\4005375141.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   annual_aqi_df = annual_aqi_df.append(df_temp, ignore_index=True)

# %%
# View Data Frame
annual_aqi_df
# Out:
#          State      County  Year  Days with AQI  Good Days  Moderate Days  \
# 0      Alabama     Baldwin  2010            274        188             80
# 1      Alabama        Clay  2010            113         79             34
# 2      Alabama     Colbert  2010            355        208            146
# 3      Alabama      DeKalb  2010            358        248            106
# 4      Alabama      Elmore  2010            241        181             55
# ...        ...         ...   ...            ...        ...            ...
# 13385  Wyoming    Sublette  2022            243        208             34
# 13386  Wyoming  Sweetwater  2022            212        176             35
# 13387  Wyoming       Teton  2022            213        200             13
# 13388  Wyoming       Uinta  2022            181        179              2
# 13389  Wyoming      Weston  2022            181        179              2
#
#        Unhealthy for Sensitive Groups Days  Unhealthy Days  \
# 0                                        6               0
# 1                                        0               0
# 2                                        1               0
# 3                                        4               0
# 4                                        5               0
# ...                                    ...             ...
# 13385                                    1               0
# 13386                                    0               1
# 13387                                    0               0
# 13388                                    0               0
# 13389                                    0               0
#
#        Very Unhealthy Days  Hazardous Days  Max AQI  90th Percentile AQI  \
# 0                        0               0      150                   71
# 1                        0               0       86                   60
# 2                        0               0      105                   67
# 3                        0               0      101                   74
# 4                        0               0      112                   71
# ...                    ...             ...      ...                  ...
# 13385                    0               0      105                   54
# 13386                    0               0      157                   57
# 13387                    0               0      100                   48
# 13388                    0               0       55                   17
# 13389                    0               0       58                   44
#
#        Median AQI  Days CO  Days NO2  Days Ozone  Days PM2.5  Days PM10
# 0              43        0         0         192          82          0
# 1              42        0         0           0         113          0
# 2              47        0         0         114         241          0
# 3              43        0         0         303          55          0
# 4              43        0         0         241           0          0
# ...           ...      ...       ...         ...         ...        ...
# 13385          46        0         0         242           1          0
# 13386          43        0         0         152          31         29
# 13387          44        1         1         209           2          0
# 13388           6        0         0           0           0        181
# 13389          40        0         0         181           0          0
#
# [13390 rows x 18 columns]

# %%
# Set 'State' to index
annual_aqi_df = annual_aqi_df.set_index("State")

annual_aqi_df.head()
# Out:
#           County  Year  Days with AQI  Good Days  Moderate Days  \
# State
# Alabama  Baldwin  2010            274        188             80
# Alabama     Clay  2010            113         79             34
# Alabama  Colbert  2010            355        208            146
# Alabama   DeKalb  2010            358        248            106
# Alabama   Elmore  2010            241        181             55
#
#          Unhealthy for Sensitive Groups Days  Unhealthy Days  \
# State
# Alabama                                    6               0
# Alabama                                    0               0
# Alabama                                    1               0
# Alabama                                    4               0
# Alabama                                    5               0
#
#          Very Unhealthy Days  Hazardous Days  Max AQI  90th Percentile AQI  \
# State
# Alabama                    0               0      150                   71
# Alabama                    0               0       86                   60
# Alabama                    0               0      105                   67
# Alabama                    0               0      101                   74
# Alabama                    0               0      112                   71
#
#          Median AQI  Days CO  Days NO2  Days Ozone  Days PM2.5  Days PM10
# State
# Alabama          43        0         0         192          82          0
# Alabama          42        0         0           0         113          0
# Alabama          47        0         0         114         241          0
# Alabama          43        0         0         303          55          0
# Alabama          43        0         0         241           0          0

# %%
# Obtain NC data
nc_aqi_df = annual_aqi_df.loc[["North Carolina"]]
nc_aqi_df
# Out:
#                    County  Year  Days with AQI  Good Days  Moderate Days  \
# State
# North Carolina   Alamance  2010            363        231            132
# North Carolina  Alexander  2010            214        132             75
# North Carolina      Avery  2010            362        280             75
# North Carolina   Buncombe  2010            364        246            114
# North Carolina   Caldwell  2010            212        149             59
# ...                   ...   ...            ...        ...            ...
# North Carolina      Rowan  2022            273        223             50
# North Carolina      Swain  2022            271        251             20
# North Carolina      Union  2022            213        187             26
# North Carolina       Wake  2022            274        226             47
# North Carolina     Yancey  2022            211        172             39
#
#                 Unhealthy for Sensitive Groups Days  Unhealthy Days  \
# State
# North Carolina                                    0               0
# North Carolina                                    7               0
# North Carolina                                    7               0
# North Carolina                                    4               0
# North Carolina                                    4               0
# ...                                             ...             ...
# North Carolina                                    0               0
# North Carolina                                    0               0
# North Carolina                                    0               0
# North Carolina                                    1               0
# North Carolina                                    0               0
#
#                 Very Unhealthy Days  Hazardous Days  Max AQI  \
# State
# North Carolina                    0               0       91
# North Carolina                    0               0      140
# North Carolina                    0               0      122
# North Carolina                    0               0      119
# North Carolina                    0               0      122
# ...                             ...             ...      ...
# North Carolina                    0               0       87
# North Carolina                    0               0       80
# North Carolina                    0               0      100
# North Carolina                    0               0      122
# North Carolina                    0               0       93
#
#                 90th Percentile AQI  Median AQI  Days CO  Days NO2  \
# State
# North Carolina                   62          43        0         0
# North Carolina                   84          46        0         0
# North Carolina                   71          44        0         0
# North Carolina                   65          44        0         0
# North Carolina                   74          44        0         0
# ...                             ...         ...      ...       ...
# North Carolina                   55          44        0         0
# North Carolina                   48          35        0         0
# North Carolina                   51          42        0         0
# North Carolina                   54          42        1         0
# North Carolina                   61          44        0         0
#
#                 Days Ozone  Days PM2.5  Days PM10
# State
# North Carolina           0         363          0
# North Carolina         214           0          0
# North Carolina         346          16          0
# North Carolina         119         245          0
# North Carolina         212           0          0
# ...                    ...         ...        ...
# North Carolina         212          61          0
# North Carolina         202          69          0
# North Carolina         213           0          0
# North Carolina         203          70          0
# North Carolina         211           0          0
#
# [521 rows x 17 columns]

# %%
# Save Data Frame as new csv
nc_aqi_df.to_csv('Resources/nc_aqi_2010-2022.csv')
